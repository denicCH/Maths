# %% [markdown]
# ## Практическое задание
#
# __1.__ Найти производную функции:
#
# ### $$y=\frac{1}{x}+\frac{2}{x^2}-\frac{5}{x^3}+\sqrt x -\sqrt[3]x+\frac{3}{\sqrt x}$$
#
# __2.__ Найти производную функции:
#
# ### $$y=x \cdot \sqrt {1+x^2}$$
#
# __3.__ Найти производную функции:
#
# ### $$y= \frac{2x}{1-x^2}$$
#
# __4*.__ Найти производную функции:
#
# ### $$y=\sqrt{x+ \sqrt{x+\sqrt x}}$$
#
# __5.__ Найти производную функции:
#
# ### $$y= \ln(x+\sqrt{x^2+1})$$
#
# __6.__ Найти производную функции:
#
# ### $$y=x \cdot \ln(x+\sqrt{x^2+1})-\sqrt{x^2+1}$$
#
# __7*.__ Найти производную функции:
#
# ### $$y=\arcsin (\sin x)$$
#
# __8*.__ Вычислить приближенное значение:
#
# ### $$\sin(1^0)=\sin\Bigl(\frac{\pi}{180}\Bigr)$$
#
#
# __9**.__ Написать на python алгоритм, по вычислению значений $\sin(x)$ для $х \in[0, 30^0]$
#
# Для проверки подойдут данные из таблицы Брадиса

# %% [markdown]
# __1.__ Найти производную функции:
#
# $$y=\frac{1}{x}+\frac{2}{x^2}-\frac{5}{x^3}+\sqrt x -\sqrt[3]x+\frac{3}{\sqrt x}$$
#
# ${\rm{y' = }}{\left( {\frac{1}{x}} \right)^\prime } + {\left( {\frac{2}{{{x^2}}}} \right)^\prime } - {\left( {\frac{5}{{{x^3}}}} \right)^\prime } + {\left( {\sqrt x } \right)^\prime } - {\left( {\sqrt[3]{x}} \right)^\prime } + {\left( {\frac{3}{{\sqrt x }}} \right)^\prime }\, = \, - {x^{ - 2}} - 4{x^{ - 3}} - 15{x^{ - 4}} + \frac{1}{2}{x^{ - \frac{1}{2}}} - 1.5{x^{\frac{1}{2}}} + 1.5{x^{ - \frac{1}{2}}}$
#
#
# __2.__ Найти производную функции:
#
# $$y=x \cdot \sqrt {1+x^2}$$
#
# $y' = x' \cdot \sqrt {1 + {x^2}} \, + x \cdot {\left( {\sqrt {1 + {x^2}} } \right)^\prime } = \,1 \cdot \sqrt {1 + {x^2}} \, + \,x \cdot \frac{1}{{2\sqrt {1 + {x^2}} }} \cdot {\left( {1 + {x^2}} \right)^\prime } = \sqrt {1 + {x^2}} \, + \,x \cdot \frac{1}{{2\sqrt {1 + {x^2}} }} \cdot 2x = \sqrt {1 + {x^2}} \, + \,\frac{{{x^2}}}{{\sqrt {1 + {x^2}} }}$
#
#
# __3.__ Найти производную функции:
#
# $$y= \frac{2x}{1-x^2}$$
#
# $y' = {\left( {\frac{{2x}}{{1 - {x^2}}}} \right)^\prime } = \frac{{{{\left( {2x} \right)}^\prime } \cdot \left( {1 - {x^2}} \right) - 2x \cdot {{\left( {1 - {x^2}} \right)}^\prime }}}{{{{\left( {1 - {x^2}} \right)}^2}}}\, = \,\frac{{2 \cdot \left( {1 - {x^2}} \right) + 4{x^2}}}{{{{\left( {1 - {x^2}} \right)}^2}}} = 2\,\frac{{1 + {x^2}}}{{{{\left( {1 - {x^2}} \right)}^2}}}$
#
#
# __4*.__ Найти производную функции:
#
# $$y=\sqrt{x+ \sqrt{x+\sqrt x}}$$
#
# $\begin{array}{l}
# y' = {\left( {\sqrt {x + \sqrt {x + \sqrt x } } } \right)^\prime } = \frac{1}{{2\sqrt {x + \sqrt {x + \sqrt x } } }} \cdot {\left( {x + \sqrt {x + \sqrt x } } \right)^\prime } = \frac{1}{{2\sqrt {x + \sqrt {x + \sqrt x } } }} \cdot \left( {1 + \frac{1}{{2\sqrt {x + \sqrt x } }} \cdot {{\left( {x + \sqrt x } \right)}^\prime }} \right) = \\
#  = \frac{1}{{2\sqrt {x + \sqrt {x + \sqrt x } } }} \cdot \left( {1 + \frac{1}{{2\sqrt {x + \sqrt x } }} \cdot \left( {1 + \frac{1}{{2\sqrt x }}} \right)} \right)
# \end{array}$
#
#
# __5.__ Найти производную функции:
#
# $$y= \ln(x+\sqrt{x^2+1})$$
#
# $\begin{array}{l}
# y' = \ln (x + \sqrt {{x^2} + 1} )' = \frac{1}{{x + \sqrt {{x^2} + 1} }} \cdot {\left( {x + \sqrt {{x^2} + 1} } \right)^\prime } = \frac{1}{{x + \sqrt {{x^2} + 1} }} \cdot \left( {1 + \frac{1}{{2\sqrt {{x^2} + 1} }} \cdot {{\left( {{x^2} + 1} \right)}^\prime }} \right) = \\
#  = \frac{1}{{x + \sqrt {{x^2} + 1} }} \cdot \left( {1 + \frac{{2x}}{{2\sqrt {{x^2} + 1} }}} \right) = \frac{1}{{x + \sqrt {{x^2} + 1} }} \cdot \left( {\frac{{\sqrt {{x^2} + 1}  + x}}{{\sqrt {{x^2} + 1} }}} \right) = \frac{1}{{\sqrt {{x^2} + 1} }}
# \end{array}$
#
#
# __6.__ Найти производную функции:
#
# $$y=x \cdot \ln(x+\sqrt{x^2+1})-\sqrt{x^2+1}$$
#
# Учтём, что $\ln (x + \sqrt {{x^2} + 1} )'\, = \,\frac{1}{{\sqrt {{x^2} + 1} }}$
#
# $\begin{array}{l}
# y' = {\left( {x \cdot \ln (x + \sqrt {{x^2} + 1} )} \right)^\prime } - {\left( {\sqrt {{x^2} + 1} } \right)^\prime }\, = \,x' \cdot \ln (x + \sqrt {{x^2} + 1} ) + x \cdot \ln (x + \sqrt {{x^2} + 1} )' - {\left( {\sqrt {{x^2} + 1} } \right)^\prime }\, = \\
#  = \ln (x + \sqrt {{x^2} + 1} ) + \frac{x}{{\sqrt {{x^2} + 1} }} - \frac{1}{{2\sqrt {{x^2} + 1} }} \cdot {\left( {{x^2} + 1} \right)^\prime } = \ln (x + \sqrt {{x^2} + 1} ) + \frac{x}{{\sqrt {{x^2} + 1} }} - \frac{x}{{\sqrt {{x^2} + 1} }} = \\
#  = \,\ln (x + \sqrt {{x^2} + 1} )
# \end{array}$
#
#
# __7*.__ Найти производную функции:
#
# $$y=\arcsin (\sin x)$$
#
# $y' = \arcsin (\sin x)' = \frac{1}{{\sqrt {1 - {{\sin }^2}x} }} \cdot {\left( {\sin x} \right)^\prime } = \frac{{\cos x}}{{\sqrt {1 - {{\sin }^2}x} }} = \frac{{\cos x}}{{{{\cos }^2}x}} = \frac{1}{{\cos x}}$
#
#
# __8*.__ Вычислить приближенное значение:
#
# $$\sin(1^0)=\sin\Bigl(\frac{\pi}{180}\Bigr)$$
#
# Для приблеженного вычисления воспользуемся формулой $f(x+\Delta x) \approx f(x)+f'(x) \cdot \Delta x$
#
# $\begin{array}{l}
# \sin (x)' = \cos (x)\\
# \sin (x + \Delta x)\, = \sin (x) + \,\cos (x) \cdot \Delta x\\
# \sin \left( {\frac{\pi }{{180}}} \right)\, = \sin \left( {0 + \frac{\pi }{{180}}} \right)\, = \sin (0) + \,\cos (0) \cdot \frac{\pi }{{180}} = 0 + 1 \cdot \frac{\pi }{{180}} = 0.017
# \end{array}$

# %% [markdown]
# __9**.__ Написать на python алгоритм, по вычислению значений $\sin(x)$ для $х \in[0, 30^0]$

# %%
import math
import pandas as pd
import numpy as np

pi = math.pi
def sin(x):     
    def res(f,delta_x):
        return f + (1-f**2)**(1/2)*delta_x*pi/180
    step = 0.01
    stop = 0
    sin = 0
    currunt = pi/180
    while stop <= x:
        sin = res(sin,step)
        stop += step
    return sin

x = np.array(range(0,31,1))
math_sin = np.array([math.sin(i*pi/180) for i in x])
sin = np.array([sin(i) for i in x])
e = math_sin - sin
d = {"x":x, "math.sin(x)":math_sin, "sin(x)":sin, "math.sin(x) - sin(x)":e}
df1 = pd.DataFrame(d)

# %%
df1.head(31)
# Out:
#      x  math.sin(x)    sin(x)  math.sin(x) - sin(x)
# 0    0     0.000000  0.000175         -1.745329e-04
# 1    1     0.017452  0.017452         -1.324581e-08
# 2    2     0.034899  0.034900         -5.305578e-08
# 3    3     0.052336  0.052510         -1.744131e-04
# 4    4     0.069756  0.069931         -1.743199e-04
# 5    5     0.087156  0.087330         -1.742000e-04
# 6    6     0.104528  0.104703         -1.740533e-04
# 7    7     0.121869  0.122043         -1.738797e-04
# 8    8     0.139173  0.139347         -1.736791e-04
# 9    9     0.156434  0.156608         -1.734515e-04
# 10  10     0.173648  0.173821         -1.731966e-04
# 11  11     0.190809  0.190982         -1.729143e-04
# 12  12     0.207912  0.208084         -1.726044e-04
# 13  13     0.224951  0.225123         -1.722668e-04
# 14  14     0.241922  0.242094         -1.719012e-04
# 15  15     0.258819  0.258991         -1.715074e-04
# 16  16     0.275637  0.275808         -1.710853e-04
# ...
